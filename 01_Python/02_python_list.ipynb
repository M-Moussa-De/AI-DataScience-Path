# %%
# 1- Vars creation
name = 'Mahmoud'
budget = 200

# %%
# 2- Items list creation
cart = ['Apple', 'Milk' ,'Bread', 'Eggs', 'Butter']
cart
# Out:
# ['Apple', 'Milk', 'Bread', 'Eggs', 'Butter']

# %%
# 3- Add & remove items from cart
cart.append('Banana')
cart.remove('Milk')
cart.insert(1, 'Orange')
cart
# Out:
# ['Apple', 'Orange', 'Bread', 'Eggs', 'Butter', 'Banana']

# %%
# 4- Math operations
price = [10, 5, 15, 20, 25, 30]
total_price = 0
for p in price:
    total_price += p

remaining_budget = budget - total_price
remaining_budget
# Out:
# 95

# %%
# 5- Extra practice
len(f'Items in cart: {len(cart)}')
cart.sort()
cart

#cart.reverse()
#cart
# Out:
# ['Apple', 'Banana', 'Bread', 'Butter', 'Eggs', 'Orange']
